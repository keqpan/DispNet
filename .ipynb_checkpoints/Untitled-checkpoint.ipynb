# %%
from pfm_utils import readPFM

t, _ = readPFM('0400.pfm')

# %%
t
# Out:
# array([[ 47.665657,  47.579063,  47.49247 , ..., 113.93849 , 114.02241 ,
#         114.16734 ],
#        [ 47.65962 ,  47.57303 ,  47.48644 , ..., 113.558395, 113.7207  ,
#         113.57648 ],
#        [ 47.653587,  47.566994,  47.480408, ..., 112.8787  , 112.96265 ,
#          95.554   ],
#        ...,
#        [267.51215 , 267.5122  , 267.51266 , ..., 267.5122  , 267.5125  ,
#         267.5122  ],
#        [268.51257 , 268.51266 , 268.5122  , ..., 268.51236 , 268.51205 ,
#         268.51205 ],
#        [269.51254 , 269.5126  , 269.5123  , ..., 269.51245 , 269.5126  ,
#         269.51245 ]], dtype=float32)

# %%
_
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0e446f3f6095> in <module>()
# ----> 1 plt.imshow(t)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     643                 self._A = pil_to_array(A)
#     644         else:
# --> 645             self._A = cbook.safe_masked_invalid(A, copy=True)
#     646
#     647         if (self._A.dtype != np.uint8 and
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#    1362
#    1363 def safe_masked_invalid(x, copy=False):
# -> 1364     x = np.array(x, subok=True, copy=copy)
#    1365     if not x.dtype.isnative:
#    1366         # Note that the argument to `byteswap` is 'inplace',
#
# /home/safin/DispNet/data_loader.py in __getitem__(self, index)
#      43     def __getitem__(self, index):
#      44         left_img = np.asarray(Image.open(self.left_scene_root + self.img_names[index]).convert("RGB"))
# ---> 45         right_img = np.asarray(Image.open(self.get_new_path(self.left_scene_root) + self.img_names[index]).convert("RGB"))
#      46         disp_map = readPFM(self.disp_root + os.path.splitext(self.img_names[index])[0] + '.pfm')
#      47 #         if self.transform is not None:
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     877         """
#     878
# --> 879         self.load()
#     880
#     881         if not mode and self.mode == "P":
#
# /opt/conda/lib/python3.6/site-packages/PIL/WebPImagePlugin.py in load(self)
#     148
#     149                 # We need to load the image data for this frame
# --> 150                 data, timestamp, duration = self._get_next()
#     151                 self.info["timestamp"] = timestamp
#     152                 self.info["duration"] = duration
#
# /opt/conda/lib/python3.6/site-packages/PIL/WebPImagePlugin.py in _get_next(self)
#     116     def _get_next(self):
#     117         # Get next frame
# --> 118         ret = self._decoder.get_next()
#     119         self.__physical_frame += 1
#     120
#
# KeyboardInterrupt:

# %%
import torch
from DispNet import DispNet
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--lr', '--learning-rate', default=2e-4, type=float,
                    metavar='LR', help='initial learning rate')
parser.add_argument('--momentum', default=0.9, type=float, metavar='M',
                    help='momentum for sgd, alpha parameter for adam')
parser.add_argument('--beta', default=0.999, type=float, metavar='M',
                    help='beta parameters for adam')
parser.add_argument('--weight-decay', '--wd', default=0, type=float,
                    metavar='W', help='weight decay')
parser.add_argument('--epochs', default=200, type=int, metavar='N',
                    help='number of total epochs to run')
parser.add_argument('-b', '--batch-size', default=10, type=int,
                    metavar='N', help='mini-batch size')
parser.add_argument('-j', '--workers', default=2, type=int, metavar='N',
                    help='number of data loading workers')

args = parser.parse_args(["--lr", "0.0001"])

disp_net = DispNet().cuda()

pretrained = False #FIXME

if pretrained:
    print("=> using pre-trained weights for Dispnet")
    weights = torch.load(args.pretrained)
    disp_net.load_state_dict(weights['state_dict'])
else:
    disp_net.init_weights()

# %%
weights = torch.load('dispnet_model_best.pth.tar')

# %%
disp_net.load_state_dict(weights['state_dict'])

# %%
args
# Out:
# Namespace(batch_size=10, beta=0.999, epochs=200, lr=0.0001, momentum=0.9, weight_decay=0, workers=2)

# %%
parameters = disp_net.parameters()
optimizer = torch.optim.Adam(parameters, args.lr,
                             betas=(args.momentum, args.beta),
                             weight_decay=args.weight_decay)

# %%
from data_loader import SequenceFolder
import torchvision

class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, left_img, right_img, disp_map):
        for t in self.transforms:
            left_img, right_img, disp_map = t(left_img, right_img, disp_map)
        return left_img, right_img, disp_map


class Normalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, left_img, right_img, disp_map):
        for tensor in [left_img, right_img]:
            for t, m, s in zip(tensor, self.mean, self.std):
                t.sub_(m).div_(s)
        return left_img, right_img, disp_map
    

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, left_img, right_img, disp_map):
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W

        left_img = torch.from_numpy(left_img.transpose((2, 0, 1)))
        right_img = torch.from_numpy(right_img.transpose((2, 0, 1)))
        disp_map = torch.from_numpy(disp_map.copy())
       
        return left_img, right_img, disp_map
    


train_transform = Compose([
    ToTensor(),
    Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_set = SequenceFolder(transform=train_transform)

# %%
train_loader = torch.utils.data.DataLoader(
    train_set, batch_size=args.batch_size, shuffle=True,
    num_workers=args.workers, pin_memory=False) #pin_memory=False

# %%
N = len(train_set)

# %%
import numpy as np
import torch.nn as nn
from torch.autograd import Variable
import tqdm
import time

loss_func = nn.MSELoss()
train_loss = []

disp_net.train()

for epoch in range(args.epochs):
    start_time = time.time()
    for left_img, right_img, disp_map in tqdm.tqdm(train_loader):
        X_batch = Variable(torch.cat((left_img, right_img), 1).float())
        y_batch = Variable(disp_map)
        disp1, disp2, disp3, disp4 = disp_net.forward(X_batch.cuda()) #concatenate on channel
        pred = disp1.squeeze(1)
        loss = loss_func(pred, y_batch.cuda())
        train_loss.append(np.asscalar(loss.data.cpu().numpy()))
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, args.epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-N // args.batch_size :])))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1749: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
#
# 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1 of 200 took 1.077s
#   training loss (in-iteration): 	12235.534180
# 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2 of 200 took 1.135s
#   training loss (in-iteration): 	12235.533203
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
#
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3 of 200 took 1.150s
#   training loss (in-iteration): 	12235.534180
# Process Process-540:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process Process-539:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e935827d7ab8> in <module>()
#      12 for epoch in range(args.epochs):
#      13     start_time = time.time()
# ---> 14     for left_img, right_img, disp_map in tqdm.tqdm(train_loader):
#      15         X_batch = Variable(torch.cat((left_img, right_img), 1).float())
#      16         y_batch = Variable(disp_map)
#
# /opt/conda/lib/python3.6/site-packages/tqdm/_tqdm.py in __iter__(self)
#     939 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     940
# --> 941             for obj in iterable:
#     942                 yield obj
#     943                 # Update and possibly print the progressbar.
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     278         while True:
#     279             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 280             idx, batch = self._get_batch()
#     281             self.batches_outstanding -= 1
#     282             if idx != self.rcvd_idx:
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     257                 raise RuntimeError('DataLoader timed out after {} seconds'.format(self.timeout))
#     258         else:
# --> 259             return self.data_queue.get()
#     260
#     261     def __next__(self):
#
# /opt/conda/lib/python3.6/multiprocessing/queues.py in get(self)
#     333     def get(self):
#     334         with self._rlock:
# --> 335             res = self._reader.recv_bytes()
#     336         # unserialize the data after having released the lock
#     337         return _ForkingPickler.loads(res)
#
# /opt/conda/lib/python3.6/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /opt/conda/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /opt/conda/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 57, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 57, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/safin/DispNet/data_loader.py", line 45, in __getitem__
#     right_img = np.asarray(Image.open(self.get_new_path(self.left_scene_root) + self.img_names[index]).convert("RGB"))
#   File "/opt/conda/lib/python3.6/site-packages/PIL/Image.py", line 879, in convert
#     self.load()
#   File "/opt/conda/lib/python3.6/site-packages/PIL/WebPImagePlugin.py", line 150, in load
#     data, timestamp, duration = self._get_next()
#   File "/opt/conda/lib/python3.6/site-packages/PIL/WebPImagePlugin.py", line 118, in _get_next
#     ret = self._decoder.get_next()
# KeyboardInterrupt

# %%
disp4.size()
# Out:
# torch.Size([5, 1, 68, 120])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(np.asarray(train_loss))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5cdc1177a0e5> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 plt.plot(np.asarray(train_loss))
#
# NameError: name 'np' is not defined

# %%
disp_net.eval()
# Out:
# DispNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU(inplace)
#     (2): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (3): ReLU(inplace)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (3): ReLU(inplace)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#   )
#   (conv6): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#   )
#   (conv7): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#   )
#   (upconv7): Sequential(
#     (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv6): Sequential(
#     (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv5): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv4): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (upconv1): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv7): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv6): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv5): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv4): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv3): Sequential(
#     (0): Conv2d(129, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv2): Sequential(
#     (0): Conv2d(65, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (iconv1): Sequential(
#     (0): Conv2d(17, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (predict_disp4): Sequential(
#     (0): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (predict_disp3): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (predict_disp2): Sequential(
#     (0): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
#   (predict_disp1): Sequential(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Sigmoid()
#   )
# )

# %%
left_img, right_img, _ = train_set[0]
X = torch.cat((left_img, right_img), 2).float()
disp1 = disp_net(X.unsqueeze(0).cuda())
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1749: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))

# %%
plt.imshow(disp1.cpu().data.numpy().reshape((540, 1920)))

# %%
plt.imshow(1/_.data.numpy())

# %%
left_img.data.numpy().shape
# Out:
# (3, 540, 960)

# %%
disp1.cpu().data.numpy().shape
# Out:
# (1, 1, 540, 1920)

# %%
plt.plot(np.asarray(train_loss))

# %%
# !conda install tqdm -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.23.0                |           py36_0          56 KB
#
# The following NEW packages will be INSTALLED:
#
#     tqdm: 4.23.0-py36_0
#
#
# Downloading and Extracting Packages
# tqdm 4.23.0############################################################# | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
for left_img, right_img, disp_map in train_loader:
    break

# %%
torch.cat((left_img, right_img), 0).size()
# Out:
# torch.Size([8, 3, 540, 960])

# %%
import os
path = "left"
for (dirpath, dirnames, filenames) in os.walk(path):
    print(dirpath, dirnames, filenames)
# Out:
# left [] ['0400.png']

# %%
os.listdir('data/frames_cleanpass_webp/35mm_focallength/scene_backwards/fast/left')
# Out:
# ['0075.webp',
#  '0206.webp',
#  '0228.webp',
#  '0202.webp',
#  '0155.webp',
#  '0295.webp',
#  '0214.webp',
#  '0008.webp',
#  '0229.webp',
#  '0089.webp',
#  '0175.webp',
#  '0227.webp',
#  '0240.webp',
#  '0038.webp',
#  '0149.webp',
#  '0136.webp',
#  '0070.webp',
#  '0002.webp',
#  '0212.webp',
#  '0020.webp',
#  '0172.webp',
#  '0195.webp',
#  '0274.webp',
#  '0119.webp',
#  '0049.webp',
#  '0226.webp',
#  '0143.webp',
#  '0013.webp',
#  '0271.webp',
#  '0185.webp',
#  '0247.webp',
#  '0006.webp',
#  '0004.webp',
#  '0137.webp',
#  '0246.webp',
#  '0165.webp',
#  '0150.webp',
#  '0281.webp',
#  '0011.webp',
#  '0029.webp',
#  '0114.webp',
#  '0198.webp',
#  '0223.webp',
#  '0210.webp',
#  '0050.webp',
#  '0154.webp',
#  '0076.webp',
#  '0187.webp',
#  '0042.webp',
#  '0183.webp',
#  '0125.webp',
#  '0205.webp',
#  '0083.webp',
#  '0028.webp',
#  '0110.webp',
#  '0287.webp',
#  '0065.webp',
#  '0043.webp',
#  '0104.webp',
#  '0095.webp',
#  '0253.webp',
#  '0291.webp',
#  '0003.webp',
#  '0098.webp',
#  '0115.webp',
#  '0064.webp',
#  '0237.webp',
#  '0063.webp',
#  '0080.webp',
#  '0243.webp',
#  '0232.webp',
#  '0058.webp',
#  '0234.webp',
#  '0055.webp',
#  '0269.webp',
#  '0216.webp',
#  '0186.webp',
#  '0074.webp',
#  '0160.webp',
#  '0068.webp',
#  '0204.webp',
#  '0292.webp',
#  '0066.webp',
#  '0101.webp',
#  '0077.webp',
#  '0284.webp',
#  '0278.webp',
#  '0145.webp',
#  '0182.webp',
#  '0211.webp',
#  '0090.webp',
#  '0151.webp',
#  '0209.webp',
#  '0252.webp',
#  '0147.webp',
#  '0218.webp',
#  '0241.webp',
#  '0096.webp',
#  '0051.webp',
#  '0131.webp',
#  '0099.webp',
#  '0275.webp',
#  '0280.webp',
#  '0201.webp',
#  '0260.webp',
#  '0197.webp',
#  '0138.webp',
#  '0071.webp',
#  '0256.webp',
#  '0082.webp',
#  '0127.webp',
#  '0084.webp',
#  '0222.webp',
#  '0130.webp',
#  '0036.webp',
#  '0085.webp',
#  '0266.webp',
#  '0048.webp',
#  '0116.webp',
#  '0215.webp',
#  '0176.webp',
#  '0057.webp',
#  '0277.webp',
#  '0289.webp',
#  '0164.webp',
#  '0023.webp',
#  '0180.webp',
#  '0159.webp',
#  '0158.webp',
#  '0297.webp',
#  '0238.webp',
#  '0168.webp',
#  '0273.webp',
#  '0123.webp',
#  '0109.webp',
#  '0242.webp',
#  '0217.webp',
#  '0128.webp',
#  '0259.webp',
#  '0251.webp',
#  '0133.webp',
#  '0037.webp',
#  '0254.webp',
#  '0091.webp',
#  '0108.webp',
#  '0141.webp',
#  '0161.webp',
#  '0019.webp',
#  '0174.webp',
#  '0290.webp',
#  '0112.webp',
#  '0162.webp',
#  '0225.webp',
#  '0030.webp',
#  '0196.webp',
#  '0034.webp',
#  '0179.webp',
#  '0156.webp',
#  '0005.webp',
#  '0113.webp',
#  '0285.webp',
#  '0053.webp',
#  '0300.webp',
#  '0276.webp',
#  '0032.webp',
#  '0188.webp',
#  '0105.webp',
#  '0046.webp',
#  '0026.webp',
#  '0025.webp',
#  '0132.webp',
#  '0067.webp',
#  '0033.webp',
#  '0282.webp',
#  '0092.webp',
#  '0047.webp',
#  '0100.webp',
#  '0022.webp',
#  '0017.webp',
#  '0146.webp',
#  '0024.webp',
#  '0054.webp',
#  '0060.webp',
#  '0270.webp',
#  '0061.webp',
#  '0014.webp',
#  '0191.webp',
#  '0107.webp',
#  '0010.webp',
#  '0111.webp',
#  '0015.webp',
#  '0190.webp',
#  '0148.webp',
#  '0118.webp',
#  '0293.webp',
#  '0117.webp',
#  '0208.webp',
#  '0299.webp',
#  '0018.webp',
#  '0244.webp',
#  '0203.webp',
#  '0122.webp',
#  '0189.webp',
#  '0140.webp',
#  '0173.webp',
#  '0094.webp',
#  '0213.webp',
#  '0294.webp',
#  '0001.webp',
#  '0009.webp',
#  '0296.webp',
#  '0262.webp',
#  '0079.webp',
#  '0272.webp',
#  '0261.webp',
#  '0166.webp',
#  '0021.webp',
#  '0279.webp',
#  '0263.webp',
#  '0194.webp',
#  '0142.webp',
#  '0163.webp',
#  '0178.webp',
#  '0248.webp',
#  '0035.webp',
#  '0157.webp',
#  '0093.webp',
#  '0235.webp',
#  '0152.webp',
#  '0236.webp',
#  '0264.webp',
#  '0031.webp',
#  '0106.webp',
#  '0199.webp',
#  '0052.webp',
#  '0124.webp',
#  '0126.webp',
#  '0250.webp',
#  '0144.webp',
#  '0040.webp',
#  '0239.webp',
#  '0012.webp',
#  '0086.webp',
#  '0102.webp',
#  '0245.webp',
#  '0200.webp',
#  '0298.webp',
#  '0181.webp',
#  '0072.webp',
#  '0134.webp',
#  '0265.webp',
#  '0224.webp',
#  '0056.webp',
#  '0255.webp',
#  '0257.webp',
#  '0059.webp',
#  '0062.webp',
#  '0286.webp',
#  '0192.webp',
#  '0027.webp',
#  '0129.webp',
#  '0087.webp',
#  '0221.webp',
#  '0268.webp',
#  '0078.webp',
#  '0267.webp',
#  '0288.webp',
#  '0153.webp',
#  '0135.webp',
#  '0249.webp',
#  '0097.webp',
#  '0230.webp',
#  '0103.webp',
#  '0184.webp',
#  '0039.webp',
#  '0120.webp',
#  '0170.webp',
#  '0081.webp',
#  '0207.webp',
#  '0171.webp',
#  '0073.webp',
#  '0044.webp',
#  '0169.webp',
#  '0177.webp',
#  '0007.webp',
#  '0193.webp',
#  '0258.webp',
#  '0283.webp',
#  '0231.webp',
#  '0088.webp',
#  '0219.webp',
#  '0045.webp',
#  '0139.webp',
#  '0220.webp',
#  '0016.webp',
#  '0167.webp',
#  '0069.webp',
#  '0041.webp',
#  '0121.webp',
#  '0233.webp']

# %%
def get_new_path(path, new_dir):
    dir_path, filename = os.path.split(path)
    dir_path, _ = os.path.split(dir_path)
    return os.path.join(dir_path, new_dir, filename)

# %%
len(os.listdir('data/frames_cleanpass_webp/35mm_focallength/scene_forwards/fast/left'))
# Out:
# 300

# %%
import scipy

# %%
import PIL
from PIL import Image

# %%
t = Image.open('data/frames_cleanpass_webp/35mm_focallength/scene_forwards/fast/left/0001.webp').convert("RGB")

# %%
t.
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F1E5013A630>

# %%
get_new_path('data/frames_cleanpass_webp/35mm_focallength/scene_backwards/slow/left/', 'right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-47ba56498178> in <module>()
# ----> 1 get_new_path('data/frames_cleanpass_webp/35mm_focallength/scene_backwards/slow/left/', 'right')
#
# NameError: name 'get_new_path' is not defined

# %%
from data_loader import SequenceFolder

# %%
t = SequenceFolder()

# %%
t[0]
# Out:
# (array([[[122, 113, 109],
#          [121, 112, 108],
#          [121, 112, 106],
#          ...,
#          [ 25,  30,  15],
#          [ 20,  26,  17],
#          [ 24,  32,  25]],
#
#         [[130, 121, 117],
#          [125, 117, 113],
#          [121, 112, 106],
#          ...,
#          [ 46,  55,  27],
#          [ 36,  46,  27],
#          [ 27,  36,  21]],
#
#         [[129, 121, 114],
#          [123, 115, 108],
#          [118, 110, 106],
#          ...,
#          [ 64,  79,  26],
#          [ 59,  74,  35],
#          [ 38,  52,  20]],
#
#         ...,
#
#         [[174, 137, 127],
#          [173, 136, 123],
#          [174, 137, 125],
#          ...,
#          [153, 151, 151],
#          [151, 148, 149],
#          [149, 147, 148]],
#
#         [[174, 137, 125],
#          [173, 136, 121],
#          [173, 137, 119],
#          ...,
#          [150, 150, 150],
#          [151, 151, 151],
#          [154, 154, 154]],
#
#         [[173, 136, 121],
#          [174, 138, 122],
#          [174, 138, 120],
#          ...,
#          [153, 153, 153],
#          [153, 153, 153],
#          [155, 155, 155]]], dtype=uint8), array([[[122, 113, 111],
#          [121, 112, 110],
#          [121, 112, 108],
#          ...,
#          [ 63,  77,  20],
#          [ 39,  49,  12],
#          [ 29,  39,  10]],
#
#         [[123, 114, 112],
#          [119, 110, 109],
#          [117, 109, 105],
#          ...,
#          [ 66,  79,  22],
#          [ 62,  73,  35],
#          [ 42,  51,  25]],
#
#         [[122, 113, 109],
#          [117, 109, 105],
#          [116, 107, 103],
#          ...,
#          [ 59,  73,  13],
#          [ 64,  75,  39],
#          [ 22,  31,   7]],
#
#         ...,
#
#         [[189, 170, 149],
#          [180, 161, 140],
#          [167, 150, 126],
#          ...,
#          [ 22,  22,  22],
#          [ 22,  22,  22],
#          [ 23,  23,  23]],
#
#         [[175, 156, 135],
#          [174, 155, 134],
#          [169, 153, 129],
#          ...,
#          [ 22,  22,  22],
#          [ 22,  22,  22],
#          [ 21,  21,  21]],
#
#         [[194, 175, 154],
#          [191, 171, 150],
#          [180, 163, 139],
#          ...,
#          [ 21,  21,  21],
#          [ 20,  20,  20],
#          [ 19,  19,  19]]], dtype=uint8), (array([[  1.4209507,   1.4204493,   1.4199477, ...,  47.51297  ,
#            48.21009  ,  48.36211  ],
#          [  1.4201981,   1.4196966,   1.4191952, ...,  47.55001  ,
#            48.23235  ,  48.417355 ],
#          [  1.4194456,   1.418944 ,   1.4184425, ...,  74.373116 ,
#            74.36311  ,  48.472607 ],
#          ...,
#          [267.51288  , 267.5128   , 267.51273  , ..., 267.5128   ,
#           267.5127   , 267.51285  ],
#          [268.51254  , 268.51273  , 268.51273  , ..., 268.513    ,
#           268.51294  , 268.51288  ],
#          [269.51276  , 269.51276  , 269.5127   , ..., 269.51276  ,
#           269.51273  , 269.51263  ]], dtype=float32),
#   1.0))

# %%
plt.imshow(l)

# %%
plt.imshow(r)

# %%
d[0]
# Out:
# array([[  1.4209507,   1.4204493,   1.4199477, ...,  47.51297  ,
#          48.21009  ,  48.36211  ],
#        [  1.4201981,   1.4196966,   1.4191952, ...,  47.55001  ,
#          48.23235  ,  48.417355 ],
#        [  1.4194456,   1.418944 ,   1.4184425, ...,  74.373116 ,
#          74.36311  ,  48.472607 ],
#        ...,
#        [267.51288  , 267.5128   , 267.51273  , ..., 267.5128   ,
#         267.5127   , 267.51285  ],
#        [268.51254  , 268.51273  , 268.51273  , ..., 268.513    ,
#         268.51294  , 268.51288  ],
#        [269.51276  , 269.51276  , 269.5127   , ..., 269.51276  ,
#         269.51273  , 269.51263  ]], dtype=float32)

# %%
plt.imshow(d[0])

# %%
t = Image.open('data/frames_cleanpass_webp/35mm_focallength/scene_backwards/slow/left/0001.webp').convert("RGB")
t
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F1E50131518>

# %%
import numpy as np
plt.imshow(np.asarray(t)[:,:,1:4])

# %%
np.asarray(t)[:3].shape
# Out:
# (3, 960, 4)

# %%
dir(PIL)
PIL.version
# Out:
# <module 'PIL.version' from '/opt/conda/lib/python3.6/site-packages/PIL/version.py'>

# %%
PIL.PILLOW_VERSION
# Out:
# '5.1.0'

# %%
dir(PIL)
# Out:
# ['BlpImagePlugin',
#  'BmpImagePlugin',
#  'BufrStubImagePlugin',
#  'CurImagePlugin',
#  'DcxImagePlugin',
#  'DdsImagePlugin',
#  'EpsImagePlugin',
#  'FitsStubImagePlugin',
#  'FliImagePlugin',
#  'FpxImagePlugin',
#  'FtexImagePlugin',
#  'GbrImagePlugin',
#  'GifImagePlugin',
#  'GimpGradientFile',
#  'GimpPaletteFile',
#  'GribStubImagePlugin',
#  'Hdf5StubImagePlugin',
#  'IcnsImagePlugin',
#  'IcoImagePlugin',
#  'ImImagePlugin',
#  'Image',
#  'ImageChops',
#  'ImageColor',
#  'ImageFile',
#  'ImageMode',
#  'ImagePalette',
#  'ImageSequence',
#  'ImtImagePlugin',
#  'IptcImagePlugin',
#  'Jpeg2KImagePlugin',
#  'JpegImagePlugin',
#  'JpegPresets',
#  'McIdasImagePlugin',
#  'MicImagePlugin',
#  'MpegImagePlugin',
#  'MpoImagePlugin',
#  'MspImagePlugin',
#  'PILLOW_VERSION',
#  'PaletteFile',
#  'PalmImagePlugin',
#  'PcdImagePlugin',
#  'PcxImagePlugin',
#  'PdfImagePlugin',
#  'PdfParser',
#  'PixarImagePlugin',
#  'PngImagePlugin',
#  'PpmImagePlugin',
#  'PsdImagePlugin',
#  'SgiImagePlugin',
#  'SpiderImagePlugin',
#  'SunImagePlugin',
#  'TgaImagePlugin',
#  'TiffImagePlugin',
#  'TiffTags',
#  'VERSION',
#  'WmfImagePlugin',
#  'XVThumbImagePlugin',
#  'XbmImagePlugin',
#  'XpmImagePlugin',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_binary',
#  '_imaging',
#  '_plugins',
#  '_util',
#  'version']
